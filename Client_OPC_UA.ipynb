# %%
import datetime
from IPython.display import clear_output
from matplotlib import pyplot as plt
import time

# # client
# from opcua import ua, Client

# namespace = "PC_Data"
# server_url = "opc.tcp://127.0.0.1:12348"
# client = Client(server_url)

# try:
#     client.connect()

#     # Now find the node
#     idx =  client.get_namespace_index(namespace)
#     objects =  client.get_objects_node()
#     functions = objects.get_child(f"{idx}:MyFunction")

#     result =  functions.call_method(f"{idx}:multiply", 7,9)
#     print(f"7 * 9 is {result}" )

# finally:
#     client.disconnect()
# plt.show()

# try:
#     while True:
#         time.sleep(1)

#         client.connect()
#         idx = str(client.get_namespace_index(namespace))
#         objects = client.get_objects_node()

#         # get node history
#         server_cpu = objects.get_child(
#             [idx+":PCData", idx+":CPU"]
#             ).read_raw_history()
#         server_ram = objects.get_child(
#             [idx+":PCData", idx+":RAM"]
#             ).read_raw_history()
#         server_battery = objects.get_child(
#             [idx+":PCData", idx+":Battery"]
#             ).read_raw_history()

#         # clear old output
#         clear_output(wait=True)

#         # plot values
#         plt.plot(
#             [datapoint.Value._value for datapoint in server_cpu],
#             label="CPU")
#         plt.plot(
#             [datapoint.Value._value for datapoint in server_ram],
#             label="RAM")
#         plt.plot(
#             [datapoint.Value._value for datapoint in server_battery],
#             label="Battery")
#         plt.ylabel('Usage %')
#         plt.xticks([])
#         plt.xlabel('Time ago')
#         plt.legend(loc='upper center')
#         plt.show()
# finally:
#     client.disconnect()

###########################################################################
## ** Here I am creating the client variable for reading the temperature **
###########################################################################

# import time
# from opcua import Client, ua
# # from opcua.crypto import security_policies
# # from OpenSSL.crypto import load_certificate, verify, FILETYPE_PEM
# import random

# # Server endpoint (update with your actual server address)
# SERVER_URL = "opc.tcp://127.0.0.1:12348"

# # User credentials (must match server-side configuration)
# USERNAME = "SMSGMBH"
# PASSWORD = "25112511"

# # **Create OPC UA Client and Set Security Policy**
# client = Client(SERVER_URL)



# # Enable security policy (Basic256Sha256) for encryption
# # client.set_security_string("Basic256Sha256,Sign,Username,None")
# # client.set_security(
# #     security_policies.SecurityPolicyBasic256Sha256,certificate_path=r"C:\Users\Jeevan.Somanna\AppData\Roaming\unifiedautomation\uaexpert\PKI\trusted\certs\UaExpert@SMS-142M [2CB9E6ED62B8E228F418E163A1CDACFA380E4BD8].der", private_key_path=r"C:\Users\Jeevan.Somanna\Downloads\private.pem"

# # )

# # Set Username and Password for authentication
# # client.set_user(USERNAME)
# # client.set_password(PASSWORD)

# try:
#     # **Connect to the OPC UA Server**
#     client.connect()
#     print("Successfully connected to the server!")

#     # **Access the RoomTemperature Variable**
#     room_temperature = client.get_node("ns=2;s=RoomTemperature")  # Update with correct namespace/index
#     print(f" Current Room Temperature: {room_temperature.get_value()}°C")



#     # **Access the Password-Protected Variable (SensitiveData)**
#     sensitive_data = client.get_node("ns=2;s=SensitiveData")  # Update with correct namespace/index
#     print(f"Sensitive Data: {sensitive_data.get_value()}")  # Only works if authentication is correct

#     # **Subscribe to RoomTemperature Updates**
#     class TemperatureHandler:
#         def datachange_notification(self, node, val, data):
#             print(f"Temperature Changed: {val}°C")

#     handler = TemperatureHandler()
#     subscription = client.create_subscription(1000, handler)
#     subscription.subscribe_data_change(room_temperature)

#     # **Modify Room Temperature Value**
#     new_temp = room_temperature.get_value() + random.uniform(-1, 1)
#     room_temperature.set_value(ua.Variant(new_temp, ua.VariantType.Double))
#     print(f" Updated Room Temperature to {new_temp}°C")

#     # Keep the client running to receive updates
#     while True:
#         time.sleep(2)

# except Exception as e:
#     print(f"Error: {e}")

# finally:
#     # **Disconnect the Client**
#     client.disconnect()
#     print(" Disconnected from server.")


##################################################################################
## ** Checking for client with the encryption and along the subscription handler**
##################################################################################
# import sys
# sys.path.insert(0, "..")
# import logging
# from IPython import embed
# from opcua import Client,ua,Node

# class SubscriptionHandler:
#     def datachange_notification(self, node:Node , val, data):
#         print(str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M %p")) + " : " + str(node) + " : " +str(val))

# if __name__ == "__main__":
#     client = Client("opc.tcp://127.0.0.1:12348")
#     #client = Client("opc.tcp://localhost:53530/OPCUA/SimulationServer/")
#     # client.set_security_string(f"Basic256Sha256,SignAndEncrypt,{r"C:\Users\Jeevan.Somanna\Downloads\certificate-example.der"},{r"C:\Users\Jeevan.Somanna\Downloads\private-key-example.pem"}")
#     client.application_uri = "urn:example.org:FreeOpcUa:python-opcua"
#     client.secure_channel_timeout = 10000
#     client.session_timeout = 10000

#     # client.set_user("SMSGMBH")
#     # client.set_password("25112511")

#     try:
#         client.connect()
#         idx = client.get_namespace_index("My_Own_Namespace")
#         print(idx)
#         root = client.get_root_node()
#         objects = client.get_objects_node()
#         node = client.get_node((f"ns={idx};i=1"))
#         child = node.get_child("2:MyVariable")
#         print(child.get_value())
#         value = client.get_node("ns=2;i=2").get_value()
#         myvar =  client.get_node("ns=2;i=2")
#         handler =  SubscriptionHandler()
#         sub =  client.create_subscription(500 , handler)
#         handle = sub.subscribe_data_change(myvar)
#         time.sleep(0.1)
#         print(value)
#         print("childs of objects are: ", objects.get_children())

#         embed()
#     finally:
#         client.disconnect()
#         sub.unsubscribe(handle)



#################################################################################
## ** Now creating the client security for username and password authentification
#################################################################################

# import socket
# import bcrypt
# from opcua import Client
# import time

# class OPC_CLIENT_SECURITY:
#     def __init__(self):
#         self.client_socket = socket.socket()

#     def init_opc_client_security(self, server_ip):
#         self.client_socket.connect((server_ip, 12350))

#     def get_opc_server_access(self, credentials):
#         print("Requesting server access....")
#         self.client_socket.send(credentials.encode())
#         result = self.client_socket.recv(1024).decode()

#         if result == "Success":
#             print("Server access granted")
#             return True
#         elif result == "Failure":
#             print("Server access denied")
#             return False

# opc_client = OPC_CLIENT_SECURITY()
# opc_client.init_opc_client_security("127.0.0.1")
# credentials = 'admin,qwerty@123'

# res = opc_client.get_opc_server_access(credentials)

# while res:

#     url = "opc.tcp://127.0.0.1:12349"

#     client = Client(url)

#     client.connect()

#     while True:
#         temp = client.get_node("ns=2;i=2")
#         temp_value = temp.get_value()
#         print("Temperature is {} ".format(temp_value))
#         time.sleep(1)




#################################################################################
## ***Now Trying to connect to the OPCUA Simulation server***
#################################################################################
from opcua import Client
import time
import sys

url = "opc.tcp://192.168.214.1:4840"
client = Client(url, timeout=10000)


try:
    client.connect()

except Exception as err:
    print(f"Could not connect to the server == {err}")
